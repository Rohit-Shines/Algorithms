# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # most important formulaes
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #
# ![image.png](attachment:image.png)
